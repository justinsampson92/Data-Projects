# %%
# %load_ext rmagic

# %%
# %%R
# regressiondata_url = "https://bspace.berkeley.edu/access/content/user/874797/stat133proj2data2a.csv"
# pricedata_url = "https://bspace.berkeley.edu/access/content/user/874797/stat133projdataprice.csv"
# regression_file= './data/raw/regressiondata.csv'
# price_file= './data/raw/pricedata.csv'
# pricedata=read.csv(price_file, header=TRUE, sep=",")
# data=read.table(regression_file, header=TRUE, sep=",")
# data$Day=sub("/", ".", data$Day)
# data$Day= sub('/', '.', data$Day)
# data$Day=paste("X", data$Day, sep="")
# Day=as.name(data$Day)
# #to access dataprice use "pricedata[,data$Day[day]]"
# Daydict=vector(mode='list', length=length(data$Day))
# names(Daydict)=data$Day
# Daydict[1:length(data$Day)]= c(1:length(data$Day))
#
# findprices=function(day){
#   if(any(names(pricedata)== day)){
#   index=as.integer(Daydict[day])
#   return(pricedata[,data$Day[index]])
#   }
#   else{return(NA)}
#
# }
#
# timetomins=function(timeofspeech){
#   x=sub(":", " ", timeofspeech)
#   a=strsplit(x, " ")
#   a=unlist(a)
#   b=as.numeric(a[1])
#   c=as.numeric(a[2])
#   if (b<8){
#     b=b+12
#   }
#   return(b*60+c-180)
#
# }
#
# timetointervalsp= function(time){
#   mins=timetomins(time)
#   if(mins < (390+60)){
#     return(c(406, 406-180))
#   }
#   if(mins > 780-120){
#     return(c(2+180, 2))
#   }
#   else{
#     return(c(406-(mins-390-60), (406-(mins-390+120))))
#   }
# }
#
# timetointervalvix= function(time){
#   mins=timetomins(time)
#   if(mins < (390+60)){
#     return(c(1219, 1219-180))
#   }
#   if(mins > 780-120){
#     return(c(2+180, 2))
#   }
#   else{
#     return(c(1219-(mins-390-60), (1219-(mins-390+120))))
#   }
# }
#
# percentchangesp=function(day, time){
#   x=timetointervalsp(time)
#   prices=findprices(day)
#   first=x[1]
#   last=x[2]
#   pfirst=as.numeric(as.character(prices[first]))
#   plast=as.numeric(as.character(prices[last]))
#   return((plast-pfirst)/pfirst)
# }
#
# percentchangevix=function(day, time){
#   x=timetointervalvix(time)
#   prices=findprices(day)
#   first=x[1]
#   last=x[2]
#   pfirst=as.numeric(as.character(prices[first]))
#   plast=as.numeric(as.character(prices[last]))
#   return((plast-pfirst)/pfirst)
# }
#
# data$ChangeVIX= mapply(percentchangevix, data$Day, data$Time)
# data$ChangeSP= mapply(percentchangesp, data$Day, data$Time)

# %% [markdown]
# ## Cumulative Analysis

# %%
# %%R
# hist(data$ChangeSP, breaks=10, col="blue", main="Histogram of S&P 500 Price Change: 180 Minute Intervals", xlab="Change in S&P 500")
# hist(data$ChangeSP, breaks=20, col="yellow", main="Histogram of S&P 500 Price Change: 180 Minute Intervals", xlab="Change in S&P 500")
# boxplot(data$ChangeSP, col="grey", main="Boxplot of Changes in S&P 500", horizontal=TRUE)

# %%
# %%R
# hist(data$ChangeVIX, breaks=10, col="blue", main="Histogram of VIX Change: 180 Minute Intervals", xlab="Change in VIX")
# hist(data$ChangeVIX, breaks=20, col="yellow", main="Histogram of VIX Change: 180 Minute Intervals", xlab="Change in VIX")
# boxplot(data$ChangeVIX, col="grey", main="Boxplot of Changes in VIX", horizontal=TRUE)

# %%
# %%R
# hist(data$Speech, breaks=15, col="red", main="Histogram of Average Speech Sentiments", xlab="Average Word Sentiment")
# boxplot(data$Speech, col="grey", main='Boxplot of Average Speech Sentiments', xlab="Average Word Sentiment")

# %% [markdown]
# ### Maximum and Minimum Sentiment Values

# %% [markdown]
# ##### Note: The Following Graphs will be labelled appropriately. The axes represent time (minutes into market hours) and price (in USD), respectively. The red verticle line on each graph will denote the time during the day when the speech was given. All code is available for modification.

# %% [markdown]
# #### Maximum Speech Sentiment Value

# %%
# %%R
# maxsent=data$Speech[data$Speech == max(data$Speech)]
# print(c("Sentiment:", as.character(maxsent)))
# print(c("Speaker:", as.character(data$Name[data$Speech == max(data$Speech)])))
# print(c("Title:", as.character(data$Title[data$Speech == max(data$Speech)])))
#
# maxsent=data$Day[data$Speech == max(data$Speech)]
# print(c("Date:", maxsent))
# maxsenttime=data$Time[data$Speech == max(data$Speech)]
# print(c("Time:", as.character(maxsenttime)))
# maxsenttimemins=timetomins(maxsenttime)-390
# print(c("Minutes into Market:",maxsenttimemins))
# hor=data$HORRep[data$Speech == max(data$Speech)]
# print(c("HOR Republicans:", hor))
# sen=data$SenateRep[data$Speech == max(data$Speech)]
# print(c("Senate Republicans:", sen))
# unemploy=data$Unemployment[data$Speech == max(data$Speech)]
# print(c("Unemployment:", unemploy))
# fedfun=data$FedFunds[data$Speech == max(data$Speech)]
# print(c("Federal Funds Rate:", fedfun))
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, maxsent][405:2])), ylab="SPY Prices", main="S&P 500 Prices on May 19, 2008", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=maxsenttimemins, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, maxsent][815:1218])), ylab="VIX Prices", main="VIX Prices on May 19, 2008", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=maxsenttimemins, col="red" )
# Out:
# [1] "Sentiment:" "0.3464"
# [1] "Speaker:" "Bush"
# [1] "Title:" ""
# [1] "Date:"    "X5.19.08"
# [1] "Time:" "11:15"
# [1] "Minutes into Market:" "105"
# [1] "HOR Republicans:" "0.455172414"
# [1] "Senate Republicans:" "0.49"
# [1] "Unemployment:" "5.4"
# [1] "Federal Funds Rate:" "1.95"

# %% [markdown]
# #### Minimum Speech Sentiment Value

# %%
# %%R
# sent=data$Speech[data$Speech == min(data$Speech)]
# print(c("Sentiment:", sent))
# print(c("Speaker:", as.character(data$Name[data$Speech == min(data$Speech)])))
# print(c("Title:", as.character(data$Title[data$Speech == min(data$Speech)])))
#
# minsent=data$Day[data$Speech == min(data$Speech)]
# print(c("Date:", minsent))
# minsenttime=data$Time[data$Speech == min(data$Speech)]
# print(c("Time:", as.character(minsenttime)))
# minsenttimemins=timetomins(minsenttime)-390
# print(c("Minutes into Market:",minsenttimemins))
# hor=data$HORRep[data$Speech == min(data$Speech)]
# print(c("HOR Republicans:", hor))
# sen=data$SenateRep[data$Speech == min(data$Speech)]
# print(c("Senate Republicans:", sen))
# unemploy=data$Unemployment[data$Speech == min(data$Speech)]
# print(c("Unemployment:", unemploy))
# fedfun=data$FedFunds[data$Speech == min(data$Speech)]
# print(c("Federal Funds Rate:", fedfun))
#
# plot(x=1:404, as.numeric(as.character(pricedata[, minsent][405:2])), ylab="SPY Prices", main="SPY Prices on October 6, 2008", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsenttimemins, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, minsent][1218:815])), ylab="VIX Prices", main="VIX Prices on October 6, 2008", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsenttimemins, col="red" )
# Out:
# [1] "Sentiment:" "-0.0625"
# [1] "Speaker:" "Bush"
# [1] "Title:" ""
# [1] "Date:"    "X10.6.08"
# [1] "Time:" "11:44"
# [1] "Minutes into Market:" "134"
# [1] "HOR Republicans:" "0.455172414"
# [1] "Senate Republicans:" "0.49"
# [1] "Unemployment:" "6.5"
# [1] "Federal Funds Rate:" "1.96"

# %% [markdown]
# In all of these cases there seems to be direct reaction to the speech, usually coorelating high sentiments with a rise in prices and low sentiments with a drop in prices. However, it is important to note that there seems to be a market correction at the end of the day, bringing SPY prices and VIX prices back to normal, pre-speech levels. This market correction and speech-price correlation will be further examined and explained later in the analaysis.

# %% [markdown]
# ### Maximum and Minimum Change in SPY Prices

# %% [markdown]
# #### Maximum 180-minute Change in SPY Prices

# %%
# %%R
# new = data$ChangeSP[!is.na(data$ChangeSP)]
# new=new[data$Day != ("X10.14.08")]
#
# new=new[!is.na(new)]
# maxvalue = max(new)
# print(c("Change:",as.numeric(maxvalue)))
# print(c("Sentiment:", (as.character((data$Speech[new==max(new)])))))
# date=data$Day[new==max(new)]
# speaker=data$Name[new==max(new)]
# print(c("Speaker:", as.character(speaker)))
# title=data$Title[data$Day==date]
# print(c("Title:", as.character(title)))
# date=data$Day[new==max(new)]
# print(c("Date:", date))
# time=data$Time[new==max(new)]
# print(c("Time:", as.character(time)))
# mins=timetomins(time)-390
# print(c("Minutes into Market:", mins))
# hor=data$HORRep[new==max(new)]
# print(c("HOR Republicans:", hor))
# sen=data$SenateRep[new==max(new)]
# print(c("Senate Republicans:", sen))
# unemploy=data$Unemployment[new==max(new)]
# print(c("Unemployment:", unemploy))
# fedfun=data$FedFunds[new==max(new)]
# print(c("Federal Funds Rate:", fedfun))
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="SPY Prices on January 18, 2008", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=mins, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][1218:815])), ylab="VIX Prices", main="VIX Prices on January 18, 2008", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=mins, col="red" )
# Out:
# [1] "Change:"          "0.10334982639939"
# [1] "Sentiment:" "0.086499"
# [1] "Speaker:" "Bush"
# [1] "Title:" ""
# [1] "Date:"    "X10.7.08"
# [1] "Time:" "2:00"
# [1] "Minutes into Market:" "270"
# [1] "HOR Republicans:" "0.455172414"
# [1] "Senate Republicans:" "0.49"
# [1] "Unemployment:" "6.5"
# [1] "Federal Funds Rate:" "2.97"

# %% [markdown]
# #### Mimimum 180-minute Change in SPY prices

# %%
# %%R
# new = data$ChangeSP[!is.na(data$ChangeSP)]
#
# maxvalue = min(new)
# print(c("Change in SPY:",maxvalue))
# sent=data$Speech[new==min(new)]
# print(c("Sentiment:", sent))
# date=data$Day[new==min(new)]
# speaker=data$Name[new==min(new)]
# print(c("Speaker:", as.character(speaker)))
# title=data$Title[data$Day==date]
# print(c("Title:", as.character(title)))
# date=data$Day[new==min(new)]
# print(c("Date:", date))
# time=data$Time[new==min(new)]
# print(c("Time:", as.character(time)))
# mins=timetomins(time)-390
# print(c("Minutes into Market:", mins))
# hor=data$HORRep[new==min(new)]
# print(c("HOR Republicans:", hor))
# sen=data$SenateRep[new==min(new)]
# print(c("Senate Republicans:", sen))
# unemploy=data$Unemployment[new==min(new)]
# print(c("Unemployment:", unemploy))
# fedfun=data$FedFunds[new==min(new)]
# print(c("Federal Funds Rate:", fedfun))
#
#
# plot(x=1:404, as.numeric(as.character(pricedata$X9.23.08[405:2])), ylab="SPY Prices", main="SPY Prices on September 23, 2008", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=mins, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata$X9.23.08[1218:815])), ylab="VIX Prices", main="VIX Prices on September 23, 2008", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=0, col="red" )
# Out:
# [1] "Change in SPY:"      "-0.0420904028652845"
# [1] "Sentiment:" "0.08198"    "0.2045"
# [1] "Speaker:" "Bush"     "Bush"
# [1] "Title:"
# [1] "Date:"    "X8.12.08" "X9.18.08"
# [1] "Time:" "1:57"  "10:00"
# [1] "Minutes into Market:" "267"
# [1] "HOR Republicans:" "0.455172414"      "0.455172414"
# [1] "Senate Republicans:" "0.49"                "0.49"
# [1] "Unemployment:" "6.1"           "6.1"
# [1] "Federal Funds Rate:" "1.95"                "2.16"

# %% [markdown]
# ### Maximum and Minimum Change in VIX Prices

# %% [markdown]
# #### Maximum 180-minute Change in VIX

# %%
# %%R
# new = data$ChangeVIX[!is.na(data$ChangeSP)]
#
# maxvalue = max(new)
# print(c("Change in VIX:",maxvalue))
# sent=data$Speech[new==max(new)]
# print(c("Sentiment:", sent))
# date=data$Day[new==max(new)]
# speaker=data$Name[new==max(new)]
# print(c("Speaker:", as.character(speaker)))
# title=data$Title[data$Day==date]
# print(c("Title:", as.character(title)))
# date=data$Day[new==max(new)]
# print(c("Date:", date))
# time=data$Time[new==max(new)]
# print(c("Time:", as.character(time)))
# mins=timetomins(time)-390
# print(c("Minutes into Market:", (as.numeric(as.character(mins)))))
# hor=data$HORRep[new==max(new)]
# print(c("HOR Republicans:", hor))
# sen=data$SenateRep[new==max(new)]
# print(c("Senate Republicans:", sen))
# unemploy=data$Unemployment[new==max(new)]
# print(c("Unemployment:", unemploy))
# fedfun=data$FedFunds[new==max(new)]
# print(c("Federal Funds Rate:", fedfun))
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[,date][2:405])), ylab="SPY Prices", main="SPY Prices on October 3, 2008", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=mins, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[,date][815:1218])), ylab="VIX Prices", main="VIX Prices on October 3, 2008", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=mins, col="red" )
# Out:
# [1] "Change in VIX:"    "0.158010012515644"
# [1] "Sentiment:" "0.13928"
# [1] "Speaker:" "Bush"
# [1] "Title:" ""
# [1] "Date:"    "X9.26.08"
# [1] "Time:" "9:30"
# [1] "Minutes into Market:" "0"
# [1] "HOR Republicans:" "0.455172414"
# [1] "Senate Republicans:" "0.49"
# [1] "Unemployment:" "6.1"
# [1] "Federal Funds Rate:" "1.08"

# %% [markdown]
# #### Mimimum 180-minute Change in Vix

# %%
# %%R
# new = data$ChangeVIX[!is.na(data$ChangeSP)]
# new=new[data$Name!="Bush"]
#
# maxvalue = min(new)
# print(c("Change in VIX:",maxvalue))
# sent=data$Speech[new==min(new)]
# print(c("Sentiment:", sent))
# date=data$Day[new==min(new)]
# speaker=data$Name[new==min(new)]
# print(c("Speaker:", as.character(speaker)))
# title=data$Title[data$Day==date]
# print(c("Title:", as.character(title)))
# date=data$Day[new==min(new)]
# print(c("Date:", date))
# time=data$Time[new==min(new)]
# print(c("Time:", as.character(time)))
# mins=timetomins(time)-390
# print(c("Minutes into Market:", "267"))
#
#
# plot(x=1:404, as.numeric(as.character(pricedata$X8.12.08[2:405])), ylab="SPY Prices", main="SPY Prices on August 12, 2008", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=267, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata$X8.12.08[815:1218])), ylab="VIX Prices", main="VIX Prices on August 12, 2008", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=267, col="red" )
#
# print("The graph represents data being returned second")
# Out:
# [1] "Change in VIX:"      "-0.0716166403370195"
# [1] "Sentiment:" "0.095238"   "0.08198"
# [1] "Speaker:" "FMOC"     "Bush"
# [1] "Title:"    "statement" ""
# [1] "Date:"    "X1.20.13" "X8.12.08"
# [1] "Time:" "16:00" "1:57"
# [1] "Minutes into Market:" "267"
# [1] "The graph represents data being returned second"

# %% [markdown]
# Now, we have looked at several interesting data points, which have covered the greatest and least SPY Change, VIX Change, and Sentiment Value within the data set. Due the great market crash in 2007, many of President Bushes speeches occured during a time of great volatility. As you may have noticed, all of the graphs above correspond to a speech given by President W. Bush. While it is possible his speeches comprise the extremes in this data set due to his ability to control the market through his speeches, it is more likely his particular circumstance of volatility caused his speeches to comprise the extreme set. In the following graphs, the data set will be further examined and analyzed, looking at the speeches of Barack Obama and Ben Bernanke. This further analysis will aid in making a more definitive conclusion about the role of speeches by prominent figures in market movement.

# %% [markdown]
# ## Barack Obama Analysis

# %% [markdown]
# #### Maximum Sentiment Value

# %%
# %%R
# new=data$Speech[data$Name == "Obama"]
# new=new[!is.na(new)]
# new=new[new!=max(new)]
# new=max(new)
# print(new)
# speak=data$Name[data$Speech==new]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$Speech==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$Speech == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$Speech == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$Speech==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on September 10, 2013", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on September 10, 2013", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# Out:
# [1] 0.2024
# [1] "Speaker:" "Obama"
# [1] "Sentiment:" "0.2024"
# [1] "Title:"                         "remarks on affordable care act"
# [1] "Date:"    "X7.18.13"
# [1] "Time:" "11:30"
# [1] "Minutes into Market:" "120"

# %% [markdown]
# #### Mimimum Sentiment Value

# %%
# %%R
# new=data$Speech[data$Name == "Obama"]
# new=new[!is.na(new)]
# new=min(new)
# print(new)
# speak=data$Name[data$Speech==new]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$Speech==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$Speech == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$Speech == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$Speech==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on September 10, 2013", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=0, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on September 10, 2013", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=0, col="red" )
# Out:
# [1] -0.00729
# [1] "Speaker:" "Obama"
# [1] "Sentiment:" "-0.00729"
# [1] "Title:"           "remarks on syria"
# [1] "Date:"    "X9.10.13"
# [1] "Time:" "9:01"
# [1] "Minutes into Market:" "-29"

# %% [markdown]
# #### Maximum 180-minute S&P 500 Change

# %%
# %%R
# new=data$ChangeSP[data$Name == "Obama"]
# new=new[!is.na(new)]
# new=max(new)
# print(new)
# speak=data$Name[data$ChangeSP==new]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$ChangeSP==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$ChangeSP == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$ChangeSP == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$ChangeSP==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on March 20, 2014", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on March 20, 2014", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# Out:
# [1] 0.006552073
# [1] "Speaker:" "Obama"
# [1] "Sentiment:" "0.10241"
# [1] "Title:"     "on ukraine"
# [1] "Date:"    "X3.20.14"
# [1] "Time:" "11:05"
# [1] "Minutes into Market:" "95"

# %% [markdown]
# #### Mimimum 180-minute S&P 500 Change

# %%
# %%R
# new=data$ChangeSP[data$Name == "Obama"]
# new=new[!is.na(new)]
# new=min(new)
# print(new)
# speak=data$Name[data$ChangeSP==new]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$ChangeSP==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$ChangeSP == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$ChangeSP == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$ChangeSP==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on October 3, 2013", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on October 3, 2013", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# Out:
# [1] -0.005255758
# [1] "Speaker:" "Obama"
# [1] "Sentiment:" "0.04858"
# [1] "Title:"               "Governement Shutdown"
# [1] "Date:"    "X10.3.13"
# [1] "Time:" "10:49"
# [1] "Minutes into Market:" "79"

# %% [markdown]
# #### Maximum 180-minute VIX Change

# %%
# %%R
# new=data$ChangeVIX[data$Name == "Obama"]
# new=new[!is.na(new)]
# new=max(new)
# print(new)
# speak=data$Name[data$ChangeVIX==new]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$ChangeVIX==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$ChangeVIX == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$ChangeVIX == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$ChangeVIX==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on August 15, 2013", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on August 15, 2013", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# Out:
# [1] 0.07361963
# [1] "Speaker:" "Obama"
# [1] "Sentiment:" "0.12592"
# [1] "Title:"           "remarks on egypt"
# [1] "Date:"    "X8.15.13"
# [1] "Time:" "10:30"
# [1] "Minutes into Market:" "60"

# %% [markdown]
# #### 2nd Minimum 180-minute VIX Change (Minimum Change was his speech "On Ukraine")

# %%
# %%R
# new=data$ChangeVIX[data$Name == "Obama"]
# new=new[!is.na(new)]
# new=new[new!=min(new)]
# new=min(new[new!=min(new)])
# print(c("VIX Change:", new))
# speak=data$Name[data$ChangeVIX==new]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$ChangeVIX==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$ChangeVIX == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$ChangeVIX == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$ChangeVIX==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on November 14, 2013", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on November 14, 2013", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# Out:
# [1] "VIX Change:"        "-0.021360759493671"
# [1] "Speaker:" "Obama"
# [1] "Sentiment:" "0.09396"
# [1] "Title:"              "Affordable care act"
# [1] "Date:"     "X11.14.13"
# [1] "Time:" "12:02"
# [1] "Minutes into Market:" "152"

# %% [markdown]
# #### Random Analysis

# %% [markdown]
# ###### (CTRL-ENTER in order to take another Random Sample for analysis)

# %%
# %%R
# change=sample(data$Speech[data$Name=="Obama"], 1)
# new=change
# speak=data$Name[data$Speech==change]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$Speech==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$Speech == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$Speech == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$Speech==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on [Check Date Above]", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on [Check Date Above]", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# Out:
# [1] "Speaker:" "Obama"
# [1] "Sentiment:" "0.120622"
# [1] "Title:"        "budget fy2015"
# [1] "Date:"   "X3.4.14"
# [1] "Time:" "11:38"
# [1] "Minutes into Market:" "128"

# %% [markdown]
# ## Ben Bernanke Analysis

# %% [markdown]
# #### Maximum Sentiment

# %%
# %%R
# spee=data$Speech[data$Name=="Bernanke"]
#
# print(c("Sentiment:", data$Speech[data$Speech==max(spee)]))
# print(c("Speaker:", as.character(data$Name[data$Speech == max(spee)])))
# print(c("Title:", as.character(data$Title[data$Speech == max(spee)])))
#
# maxsent=data$Day[data$Speech == max(spee)]
# print(c("Date:", maxsent))
# maxsenttime=data$Time[data$Speech == max(spee)]
# print(c("Time:", as.character(maxsenttime)))
# maxsenttimemins=timetomins(maxsenttime)-390
# print(c("Minutes into Market:",maxsenttimemins))
# plot(x=1:404, as.numeric(as.character(pricedata[, maxsent][405:2])), ylab="SPY Prices", main="S&P 500 Prices on August 7, 2012", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=maxsenttimemins, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, maxsent][815:1218])), ylab="VIX Prices", main="VIX Prices on August 7, 2012", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=maxsenttimemins, col="red" )
# Out:
# [1] "Sentiment:" "0.294407"
# [1] "Speaker:" "Bernanke"
# [1] "Title:"              "Financial Education"
# [1] "Date:"   "X8.7.12"
# [1] "Time:" "2:30"
# [1] "Minutes into Market:" "300"

# %% [markdown]
# #### Minimum Sentiment

# %%
# %%R
# new=data$Speech[data$Name == "Bernanke"]
# new=new[!is.na(new)]
# new=min(new)
# print(new)
# speak=data$Name[data$Speech==new]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$Speech==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$Speech == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$Speech == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$Speech==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on March 26, 2012", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=0, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on March 26, 2012", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=0, col="red" )
# Out:
# [1] -0.02506
# [1] "Speaker:" "Bernanke"
# [1] "Sentiment:" "-0.02506"
# [1] "Title:"
# [2] "Recent Developments in the Labor Market"
# [1] "Date:"    "X3.26.12"
# [1] "Time:" "8:00"
# [1] "Minutes into Market:" "-90"

# %% [markdown]
# #### Maximum 180-Minute S&P 500 Change

# %%
# %%R
# new=data$ChangeSP[data$Name == "Bernanke"]
# new=new[!is.na(new)]
# new=max(new)
# print(c("Change:",new))
# speak=data$Name[data$ChangeSP==new]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$ChangeSP==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$ChangeSP == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$ChangeSP == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$ChangeSP==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on November 8, 2013", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on November 8, 2013", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# Out:
# [1] "Change:"             "0.00465842033590547"
# [1] "Speaker:" "Bernanke"
# [1] "Sentiment:" "0.069087"
# [1] "Title:"
# [2] "The Crisis as a Classic Financial Panic"
# [1] "Date:"    "X11.8.13"
# [1] "Time:" "3:30"
# [1] "Minutes into Market:" "360"

# %% [markdown]
# #### Minimum 180-minute S&P 500 Change

# %%
# %%R
# new=data$ChangeSP[data$Name == "Bernanke"]
# new=new[!is.na(new)]
# new=min(new)
# print(c("Change:",new))
# speak=data$Name[data$ChangeSP==new]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$ChangeSP==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$ChangeSP == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$ChangeSP == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$ChangeSP==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on October 1, 2012", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on October 1, 2012", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# Out:
# [1] "Change:"              "-0.00378272053260705"
# [1] "Speaker:" "Bernanke"
# [1] "Sentiment:" "0.12969"
# [1] "Title:"
# [2] "Five Questions about Federal Reserve and Monetary Policy"
# [1] "Date:"    "X10.1.12"
# [1] "Time:" "12:30"
# [1] "Minutes into Market:" "180"

# %% [markdown]
# #### Maximum VIX Change

# %%
# %%R
# new=data$ChangeVIX[data$Name == "Bernanke"]
# new=new[!is.na(new)]
# new=max(new)
# print(c("Change:",new))
# speak=data$Name[data$ChangeVIX==new]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$ChangeVIX==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$ChangeVIX == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$ChangeVIX == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$ChangeVIX==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on March 14, 2014", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on March 14, 2014", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# Out:
# [1] "Change:"            "0.0479729729729729"
# [1] "Speaker:" "Bernanke"
# [1] "Sentiment:" "0.18566"
# [1] "Title:"            "Community Banking"
# [1] "Date:"    "X3.14.12"
# [1] "Time:" "10:00"
# [1] "Minutes into Market:" "30"

# %% [markdown]
# #### Minimum VIX Change

# %%
# %%R
# new=data$ChangeVIX[data$Name == "Bernanke"]
# new=new[!is.na(new)]
# new=min(new)
# print(c("Change:",new))
# speak=data$Name[data$ChangeVIX==new]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$ChangeVIX==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$ChangeVIX == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$ChangeVIX == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$ChangeVIX==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on March 20, 2014", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on March 20, 2014", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# Out:
# [1] "Change:"             "-0.0610782175132441"
# [1] "Speaker:" "Bernanke"
# [1] "Sentiment:" "0.15767"
# [1] "Title:"
# [2] "The Effects of the Great Recession on Central Bank Doctrine and Practice "
# [1] "Date:"     "X10.18.11"
# [1] "Time:" "1:15"
# [1] "Minutes into Market:" "225"

# %% [markdown]
# #### Random Analysis

# %% [markdown]
# ###### (CTRL-ENTER in order to take another Random Sample for analysis)

# %%
# %%R
# change=sample(data$Speech[data$Name=="Bernanke"], 1)
# new=change
# speak=data$Name[data$Speech==change]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$Speech==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$Speech == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$Speech == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$Speech==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on [Check Date Above]", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on [Check Date Above]", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# Out:
# [1] "Speaker:" "Bernanke"
# [1] "Sentiment:" "0.294407"
# [1] "Title:"              "Financial Education"
# [1] "Date:"   "X8.7.12"
# [1] "Time:" "2:30"
# [1] "Minutes into Market:" "300"

# %% [markdown]
# ## FMOC

# %% [markdown]
# #### Random Analysis

# %% [markdown]
# ###### (CTRL-ENTER in order to take another Random Sample for analysis)

# %%
# %%R
# change=sample(data$Speech[data$Name=="FMOC"], 1)
# new=change
# speak=data$Name[data$Speech==change]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$Speech==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$Speech == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$Speech == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$Speech==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on [Check Date Above]", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on [Check Date Above]", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# Out:
# [1] "Speaker:" "FMOC"
# [1] "Sentiment:" "0.182539"
# [1] "Title:"    "statement"
# [1] "Date:"   "X5.1.13"
# [1] "Time:" "14:00"
# [1] "Minutes into Market:" "270"

# %% [markdown]
# ## Bush

# %% [markdown]
# #### Random Analysis

# %% [markdown]
# ###### (CTRL-ENTER in order to take another Random Sample for analysis)

# %%
# %%R
# change=sample(data$Speech[data$Name=="Bush"], 1)
# new=change
# speak=data$Name[data$Speech==change]
# speak=as.character(speak[!is.na(speak)])
# print(c("Speaker:", speak))
# sent=data$Speech[data$Speech==new]
# sent=as.character(sent[!is.na(sent)])
# print(c("Sentiment:", sent))
# title=as.character(data$Title[data$Speech == new])
# title=title[!is.na(title)]
# print(c("Title:", as.character(title)))
# date=as.character(data$Day[data$Speech == new])
# date=date[!is.na(date)]
# print(c("Date:", date))
# time=as.character(data$Time[data$Speech==new])
# time=time[!is.na(time)]
# print(c("Time:", as.character(time)))
# minsin=timetomins(time)-390
# print(c("Minutes into Market:", minsin))
#
#
#
#
# plot(x=1:404, as.numeric(as.character(pricedata[, date][405:2])), ylab="SPY Prices", main="S&P 500 Prices on [Check Date Above]", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# plot(x=1:404, as.numeric(as.character(pricedata[, date][815:1218])), ylab="VIX Prices", main="VIX Prices on [Check Date Above]", xlab="Minutes into Market Hours | 9:30-4:00")
# abline(v=minsin, col="red" )
# Out:
# [1] "Speaker:" "Bush"
# [1] "Sentiment:" "0.17186"
# [1] "Title:" ""
# [1] "Date:"     "X10.15.08"
# [1] "Time:" "9:57"
# [1] "Minutes into Market:" "27"

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Analysis of this data set leads to the following conclusion: the market evidently reacts to speeches given by key political/financial figures, often reacting in a way coorelating to the sentiment of the speech. However, this market reaction does not result in long term price changes; the price change provoked by a political speech experiences a correction within the next few hours.

# %% [markdown]
# This "market correction" can be seen in the trend reversal that often takes the price back to pre-speech levels. This reversal is either the price rising after a post-speech price-drop or a price-drop following a post-speech price spike. This "market correction" can be seen repeatedly throughout the data set. The existence of this "correction" is an interesting aspect of this analysis. This "correction" can be well explained through theories in behavioral finance.

# %% [markdown]
# As seen in all of these samples, regardless of the sentiment of the speech, no speech ever causes more than a 10% change in the market. In these examples, one could argue that the oscillating prices over the course of a day are just due to noise. Many argue these price movements are random and are uncorrelated to the occurrence of a speech; however, there is good explation now for these oscillations--an explanation that well-relates to this project. Behavioral Financial Thoery splits the market participants into two groups. These two groups are institutional investors (Goldman Sachs, Merrill Lynch, Morgan Stanley employees) and Type-B&C Investors (not involved in the markets daily).

# %% [markdown]
# Some of this theory, and my explanation to certain phenomena in this data, cites the reason for market noise or constant short-term market corrections as an asymmetry of information between these two groups. Type-B&C Investors have limited information regarding the market. They do not subscribe to expensive financial news or instruments as do financial professionals. Their source for information regarding the market is public news, advice, and their own judgement of market history. On the other hand, institutional investors have a plethora of information and financial education at their fingertips. Because of their close connections with government officials and well-funded research budget, financial professionals are usually well aware of the current state and trend of the market. In fact, they have likely already set the market trend with their investments made upon initially receiving their financial information. Oppositely, Type-B&C investors do not have this information prior to the speeches given by political officials. A speech given by a political official is one of their largest sources for financial information, and this is the information they usually use for their investments. Because political officials charge their speeches with rhetoric, the positivity or negativity of their speech can often affect how it recieved by these Type-B&C investors; thus, they are often provoked to invest according to the sentiment of the speech. This release of information is the explanation for immediate market reaction to a speech. Type-B&C investors react to the most currently available information, and often act emotionally due to their lack of finanial equipment and education.

# %% [markdown]
# These B&C Investors help explain the direct and immediate price and sentiment correlation; however, I must still account for the correction that follows these price movements. In almost every case of trend reversal due to a speech, the market quickly reverses again to pre-speech levels. The reason for this "correction" is the superior information held by institutional investors. As explained previously, institutional investors often hold information divulged to an audience in a speech before the speech even occurs. They have already used this information to invest accordingly, and in doing so have established their own trend. Speeches can often reverse this trend or amplify it, depending on its sentiment and reception. Regardless, these speeches often move the market from its current trend. Because of their asymmetric knowledge of the market, institutional investors use this trend deviation as an avenue for profit. Since they are already confident of the market trend and financial history, they know a speech cannot completely shift a market. So, with this deviation they either sell stocks at an overvalued price, or buy stocks at an undervalued price, thus rebalancing the market to pre-speech price levels.

# %% [markdown]
# This theory and explanation inherits from Behavioral Economic Theory.

# %% [markdown]
# Overall, this verbose explanation set aside, the conclusion to this analysis is as follows. The market reacts to speeches given by political officials. Depending on the topic and its relevance to the market, the sentiment of a given speech has shown to be directly correlated to price movements. EG) Large sentiment value correlates with SPY price spikes and drops in the VIX price. Many samples in this dataset show this correlation for both the S&P and the VIX, others show a correlation for only the VIX or S&P, and others show no correlation. However, conclusively, there is a correlation between the two and I believe revising and updating the sentiment analysis program could help better coorelate the two.

# %% [markdown]
# ##### Thank you for reading, and if you would like, please do explore the data further by utilizing the "Random Analysis" cells. If you have any other questions regarding the project, please contact brandonjflannery@berkeley.edu.
